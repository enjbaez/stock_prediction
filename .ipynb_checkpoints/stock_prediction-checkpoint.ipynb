# %%
import tensorflow as tf
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import LSTM, Dense, Dropout, Bidirectional
from tensorflow.keras.callbacks import ModelCheckpoint, TensorBoard
from sklearn import preprocessing
from sklearn.model_selection import train_test_split
from sklearn.metrics import accuracy_score
from yahoo_fin import stock_info as si
from collections import deque
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import time
import os
import random

# %%
# set seed, so we can get the same results after rerunning several times
np.random.seed(314)
tf.random.set_seed(314)
random.seed(314)

# %%
def load_data(ticker, n_steps=50, scale=True, shuffle=True, lookup_step=1, 
                test_size=0.2, feature_columns=['adjclose', 'volume', 'open', 'high', 'low']):
    """
    Loads data from Yahoo Finance source, as well as scaling, shuffling, normalizing and splitting.
    Params:
        ticker (str/pd.DataFrame): the ticker you want to load, examples include AAPL, TESL, etc.
        n_steps (int): the historical sequence length (i.e window size) used to predict, default is 50
        scale (bool): whether to scale prices from 0 to 1, default is True
        shuffle (bool): whether to shuffle the data, default is True
        lookup_step (int): the future lookup step to predict, default is 1 (e.g next day)
        test_size (float): ratio for test data, default is 0.2 (20% testing data)
        feature_columns (list): the list of features to use to feed into the model, default is everything grabbed from yahoo_fin
    """
    # see if ticker is already a loaded stock from yahoo finance
    if isinstance(ticker, str):
        # load it from yahoo_fin library
        df = si.get_data(ticker)
    elif isinstance(ticker, pd.DataFrame):
        # already loaded, use it directly
        df = ticker
    else:
        raise TypeError("ticker can be either a str or a `pd.DataFrame` instances")
    # this will contain all the elements we want to return from this function
    result = {}
    # we will also return the original dataframe itself
    result['df'] = df.copy()
    # make sure that the passed feature_columns exist in the dataframe
    for col in feature_columns:
        assert col in df.columns, f"'{col}' does not exist in the dataframe."
    if scale:
        column_scaler = {}
        # scale the data (prices) from 0 to 1
        for column in feature_columns:
            scaler = preprocessing.MinMaxScaler()
            df[column] = scaler.fit_transform(np.expand_dims(df[column].values, axis=1))
            column_scaler[column] = scaler
        # add the MinMaxScaler instances to the result returned
        result["column_scaler"] = column_scaler
    # add the target column (label) by shifting by `lookup_step`
    df['future'] = df['adjclose'].shift(-lookup_step)
    # last `lookup_step` columns contains NaN in future column
    # get them before droping NaNs
    last_sequence = np.array(df[feature_columns].tail(lookup_step))
    # drop NaNs
    df.dropna(inplace=True)
    sequence_data = []
    sequences = deque(maxlen=n_steps)
    for entry, target in zip(df[feature_columns].values, df['future'].values):
        sequences.append(entry)
        if len(sequences) == n_steps:
            sequence_data.append([np.array(sequences), target])
    # get the last sequence by appending the last `n_step` sequence with `lookup_step` sequence
    # for instance, if n_steps=50 and lookup_step=10, last_sequence should be of 60 (that is 50+10) length
    # this last_sequence will be used to predict future stock prices not available in the dataset
    last_sequence = list(sequences) + list(last_sequence)
    last_sequence = np.array(last_sequence)
    # add to result
    result['last_sequence'] = last_sequence
    # construct the X's and y's
    X, y = [], []
    for seq, target in sequence_data:
        X.append(seq)
        y.append(target)
    # convert to numpy arrays
    X = np.array(X)
    y = np.array(y)
    # reshape X to fit the neural network
    X = X.reshape((X.shape[0], X.shape[2], X.shape[1]))
    # split the dataset
    result["X_train"], result["X_test"], result["y_train"], result["y_test"] = train_test_split(X, y, 
                                                                               test_size=test_size, shuffle=shuffle)
    # return the result
    return result

# %%
def create_model(sequence_length, units=256, cell=LSTM, n_layers=2, dropout=0.3,
                loss="mean_absolute_error", optimizer="rmsprop", bidirectional=False):
    model = Sequential()
    for i in range(n_layers):
        if i == 0:
            # first layer
            if bidirectional:
                model.add(Bidirectional(cell(units, return_sequences=True), input_shape=(None, sequence_length)))
            else:
                model.add(cell(units, return_sequences=True, input_shape=(None, sequence_length)))
        elif i == n_layers - 1:
            # last layer
            if bidirectional:
                model.add(Bidirectional(cell(units, return_sequences=False)))
            else:
                model.add(cell(units, return_sequences=False))
        else:
            # hidden layers
            if bidirectional:
                model.add(Bidirectional(cell(units, return_sequences=True)))
            else:
                model.add(cell(units, return_sequences=True))
        # add dropout after each layer
        model.add(Dropout(dropout))
    model.add(Dense(1, activation="linear"))
    model.compile(loss=loss, metrics=["mean_absolute_error"], optimizer=optimizer)
    return model

# %%
# Window size or the sequence length
N_STEPS = 70
# Lookup step, 1 is the next day
LOOKUP_STEP = 1
# test ratio size, 0.2 is 20%
TEST_SIZE = 0.2
# features to use
FEATURE_COLUMNS = ["adjclose", "volume", "open", "high", "low"]
# date now
date_now = time.strftime("%Y-%m-%d")
### model parameters
N_LAYERS = 3
# LSTM cell
CELL = LSTM
# 256 LSTM neurons
UNITS = 256
# 40% dropout
DROPOUT = 0.4
# whether to use bidirectional RNNs
BIDIRECTIONAL = False
### training parameters
# mean absolute error loss
# LOSS = "mae"
# huber loss
LOSS = "huber_loss"
OPTIMIZER = "adam"
BATCH_SIZE = 64
EPOCHS = 400
# Tesla stock market
ticker = "TSLA"
ticker_data_filename = os.path.join("data", f"{ticker}_{date_now}.csv")
# model name to save, making it as unique as possible based on parameters
model_name = f"{date_now}_{ticker}-{LOSS}-{OPTIMIZER}-{CELL.__name__}-seq-{N_STEPS}-step-{LOOKUP_STEP}-layers-{N_LAYERS}-units-{UNITS}"
if BIDIRECTIONAL:
    model_name += "-b"

# %%
# create these folders if they does not exist
if not os.path.isdir("results"):
    os.mkdir("results")
if not os.path.isdir("logs"):
    os.mkdir("logs")
if not os.path.isdir("data"):
    os.mkdir("data")

# %%
# load the data
data = load_data(ticker, N_STEPS, lookup_step=LOOKUP_STEP, test_size=TEST_SIZE, feature_columns=FEATURE_COLUMNS)
# save the dataframe
data["df"].to_csv(ticker_data_filename)
# construct the model
model = create_model(N_STEPS, loss=LOSS, units=UNITS, cell=CELL, n_layers=N_LAYERS,
                    dropout=DROPOUT, optimizer=OPTIMIZER, bidirectional=BIDIRECTIONAL)
# some tensorflow callbacks
checkpointer = ModelCheckpoint(os.path.join("results", model_name + ".h5"), save_weights_only=True, save_best_only=True, verbose=1)
tensorboard = TensorBoard(log_dir=os.path.join("logs", model_name))
history = model.fit(data["X_train"], data["y_train"],
                    batch_size=BATCH_SIZE,
                    epochs=EPOCHS,
                    validation_data=(data["X_test"], data["y_test"]),
                    callbacks=[checkpointer, tensorboard],
                    verbose=1)
model.save(os.path.join("results", model_name) + ".h5")
# Out:
# Train on 2000 samples, validate on 500 samples
# Epoch 1/400
# 1984/2000 [============================>.] - ETA: 0s - loss: 0.0014 - mean_absolute_error: 0.0325
# Epoch 00001: val_loss improved from inf to 0.00030, saving model to results\2020-09-12_TSLA-huber_loss-adam-LSTM-seq-70-step-1-layers-3-units-256.h5
# 2000/2000 [==============================] - 10s 5ms/sample - loss: 0.0014 - mean_absolute_error: 0.0324 - val_loss: 3.0047e-04 - val_mean_absolute_error: 0.0161
# Epoch 2/400
# 1984/2000 [============================>.] - ETA: 0s - loss: 6.7067e-04 - mean_absolute_error: 0.0204
# Epoch 00002: val_loss did not improve from 0.00030
# 2000/2000 [==============================] - 5s 2ms/sample - loss: 6.6707e-04 - mean_absolute_error: 0.0203 - val_loss: 6.4456e-04 - val_mean_absolute_error: 0.0232
# Epoch 3/400
# 1984/2000 [============================>.] - ETA: 0s - loss: 8.5365e-04 - mean_absolute_error: 0.0233
# Epoch 00003: val_loss did not improve from 0.00030
# 2000/2000 [==============================] - 4s 2ms/sample - loss: 8.5175e-04 - mean_absolute_error: 0.0233 - val_loss: 4.4055e-04 - val_mean_absolute_error: 0.0205
# Epoch 4/400
# 1984/2000 [============================>.] - ETA: 0s - loss: 5.6235e-04 - mean_absolute_error: 0.0190
# Epoch 00004: val_loss improved from 0.00030 to 0.00024, saving model to results\2020-09-12_TSLA-huber_loss-adam-LSTM-seq-70-step-1-layers-3-units-256.h5
# 2000/2000 [==============================] - 4s 2ms/sample - loss: 5.6071e-04 - mean_absolute_error: 0.0190 - val_loss: 2.4457e-04 - val_mean_absolute_error: 0.0142
# Epoch 5/400
# 1984/2000 [============================>.] - ETA: 0s - loss: 4.7474e-04 - mean_absolute_error: 0.0176
# Epoch 00005: val_loss improved from 0.00024 to 0.00021, saving model to results\2020-09-12_TSLA-huber_loss-adam-LSTM-seq-70-step-1-layers-3-units-256.h5
# 2000/2000 [==============================] - 4s 2ms/sample - loss: 4.7476e-04 - mean_absolute_error: 0.0176 - val_loss: 2.1015e-04 - val_mean_absolute_error: 0.0122
# Epoch 6/400
# 1984/2000 [============================>.] - ETA: 0s - loss: 7.3732e-04 - mean_absolute_error: 0.0210- ETA: 3s - loss: 6.8968e-04 - me
# Epoch 00006: val_loss did not improve from 0.00021
# 2000/2000 [==============================] - 5s 2ms/sample - loss: 7.3323e-04 - mean_absolute_error: 0.0210 - val_loss: 6.0496e-04 - val_mean_absolute_error: 0.0186
# Epoch 7/400
# 1984/2000 [============================>.] - ETA: 0s - loss: 6.3691e-04 - mean_absolute_error: 0.0236
# Epoch 00007: val_loss did not improve from 0.00021
# 2000/2000 [==============================] - 5s 2ms/sample - loss: 6.3368e-04 - mean_absolute_error: 0.0236 - val_loss: 3.2237e-04 - val_mean_absolute_error: 0.0143
# Epoch 8/400
# 1984/2000 [============================>.] - ETA: 0s - loss: 7.3182e-04 - mean_absolute_error: 0.0210
# Epoch 00008: val_loss did not improve from 0.00021
# 2000/2000 [==============================] - 4s 2ms/sample - loss: 7.2994e-04 - mean_absolute_error: 0.0209 - val_loss: 2.3164e-04 - val_mean_absolute_error: 0.0136
# Epoch 9/400
# 1984/2000 [============================>.] - ETA: 0s - loss: 6.0884e-04 - mean_absolute_error: 0.0178
# Epoch 00009: val_loss did not improve from 0.00021
# 2000/2000 [==============================] - 4s 2ms/sample - loss: 6.0724e-04 - mean_absolute_error: 0.0178 - val_loss: 5.8301e-04 - val_mean_absolute_error: 0.0220
# Epoch 10/400
# 1984/2000 [============================>.] - ETA: 0s - loss: 5.4522e-04 - mean_absolute_error: 0.0193
# Epoch 00010: val_loss did not improve from 0.00021
# 2000/2000 [==============================] - 4s 2ms/sample - loss: 5.4212e-04 - mean_absolute_error: 0.0192 - val_loss: 2.1790e-04 - val_mean_absolute_error: 0.0120
# Epoch 11/400
# 1984/2000 [============================>.] - ETA: 0s - loss: 6.7638e-04 - mean_absolute_error: 0.0196
# Epoch 00011: val_loss improved from 0.00021 to 0.00017, saving model to results\2020-09-12_TSLA-huber_loss-adam-LSTM-seq-70-step-1-layers-3-units-256.h5
# 2000/2000 [==============================] - 4s 2ms/sample - loss: 6.7337e-04 - mean_absolute_error: 0.0196 - val_loss: 1.7404e-04 - val_mean_absolute_error: 0.0099
# Epoch 12/400
# 1984/2000 [============================>.] - ETA: 0s - loss: 5.6979e-04 - mean_absolute_error: 0.0190
# Epoch 00012: val_loss did not improve from 0.00017
# 2000/2000 [==============================] - 4s 2ms/sample - loss: 5.6595e-04 - mean_absolute_error: 0.0190 - val_loss: 2.6721e-04 - val_mean_absolute_error: 0.0134
# Epoch 13/400
# 1984/2000 [============================>.] - ETA: 0s - loss: 3.9274e-04 - mean_absolute_error: 0.0161
# Epoch 00013: val_loss improved from 0.00017 to 0.00017, saving model to results\2020-09-12_TSLA-huber_loss-adam-LSTM-seq-70-step-1-layers-3-units-256.h5
# 2000/2000 [==============================] - 5s 2ms/sample - loss: 3.9079e-04 - mean_absolute_error: 0.0161 - val_loss: 1.6841e-04 - val_mean_absolute_error: 0.0099
# Epoch 14/400
# 1984/2000 [============================>.] - ETA: 0s - loss: 5.9562e-04 - mean_absolute_error: 0.0186
# Epoch 00014: val_loss did not improve from 0.00017
# 2000/2000 [==============================] - 4s 2ms/sample - loss: 5.9488e-04 - mean_absolute_error: 0.0186 - val_loss: 8.0098e-04 - val_mean_absolute_error: 0.0270
# Epoch 15/400
# 1984/2000 [============================>.] - ETA: 0s - loss: 7.1190e-04 - mean_absolute_error: 0.0219
# Epoch 00015: val_loss improved from 0.00017 to 0.00013, saving model to results\2020-09-12_TSLA-huber_loss-adam-LSTM-seq-70-step-1-layers-3-units-256.h5
# 2000/2000 [==============================] - 4s 2ms/sample - loss: 7.1070e-04 - mean_absolute_error: 0.0219 - val_loss: 1.2543e-04 - val_mean_absolute_error: 0.0107
# Epoch 16/400
# 1984/2000 [============================>.] - ETA: 0s - loss: 3.8479e-04 - mean_absolute_error: 0.0148
# Epoch 00016: val_loss improved from 0.00013 to 0.00010, saving model to results\2020-09-12_TSLA-huber_loss-adam-LSTM-seq-70-step-1-layers-3-units-256.h5
# 2000/2000 [==============================] - 4s 2ms/sample - loss: 3.8227e-04 - mean_absolute_error: 0.0148 - val_loss: 9.9307e-05 - val_mean_absolute_error: 0.0080
# Epoch 17/400
# 1984/2000 [============================>.] - ETA: 0s - loss: 4.6752e-04 - mean_absolute_error: 0.0176
# Epoch 00017: val_loss did not improve from 0.00010
# 2000/2000 [==============================] - 4s 2ms/sample - loss: 4.6509e-04 - mean_absolute_error: 0.0176 - val_loss: 1.8299e-04 - val_mean_absolute_error: 0.0127
# Epoch 18/400
# 1984/2000 [============================>.] - ETA: 0s - loss: 3.1458e-04 - mean_absolute_error: 0.0136
# Epoch 00018: val_loss improved from 0.00010 to 0.00009, saving model to results\2020-09-12_TSLA-huber_loss-adam-LSTM-seq-70-step-1-layers-3-units-256.h5
# 2000/2000 [==============================] - 4s 2ms/sample - loss: 3.1276e-04 - mean_absolute_error: 0.0136 - val_loss: 9.1363e-05 - val_mean_absolute_error: 0.0075
# Epoch 19/400
# 1984/2000 [============================>.] - ETA: 0s - loss: 2.7924e-04 - mean_absolute_error: 0.0137
# Epoch 00019: val_loss did not improve from 0.00009
# 2000/2000 [==============================] - 4s 2ms/sample - loss: 2.7751e-04 - mean_absolute_error: 0.0137 - val_loss: 1.3432e-04 - val_mean_absolute_error: 0.0098
# Epoch 20/400
# 1984/2000 [============================>.] - ETA: 0s - loss: 2.8324e-04 - mean_absolute_error: 0.0128
# Epoch 00020: val_loss improved from 0.00009 to 0.00009, saving model to results\2020-09-12_TSLA-huber_loss-adam-LSTM-seq-70-step-1-layers-3-units-256.h5
# 2000/2000 [==============================] - 5s 3ms/sample - loss: 2.8139e-04 - mean_absolute_error: 0.0127 - val_loss: 8.6641e-05 - val_mean_absolute_error: 0.0083
# Epoch 21/400
# 1984/2000 [============================>.] - ETA: 0s - loss: 2.8743e-04 - mean_absolute_error: 0.0130
# Epoch 00021: val_loss improved from 0.00009 to 0.00006, saving model to results\2020-09-12_TSLA-huber_loss-adam-LSTM-seq-70-step-1-layers-3-units-256.h5
# 2000/2000 [==============================] - 5s 2ms/sample - loss: 2.8587e-04 - mean_absolute_error: 0.0130 - val_loss: 5.8524e-05 - val_mean_absolute_error: 0.0066
# Epoch 22/400
# 1984/2000 [============================>.] - ETA: 0s - loss: 3.1218e-04 - mean_absolute_error: 0.0132
# Epoch 00022: val_loss did not improve from 0.00006
# 2000/2000 [==============================] - 4s 2ms/sample - loss: 3.1029e-04 - mean_absolute_error: 0.0131 - val_loss: 1.3572e-04 - val_mean_absolute_error: 0.0097
# Epoch 23/400
# 1984/2000 [============================>.] - ETA: 0s - loss: 2.7781e-04 - mean_absolute_error: 0.0124
# Epoch 00023: val_loss did not improve from 0.00006
# 2000/2000 [==============================] - 4s 2ms/sample - loss: 2.7960e-04 - mean_absolute_error: 0.0125 - val_loss: 4.1886e-04 - val_mean_absolute_error: 0.0196
# Epoch 24/400
# 1984/2000 [============================>.] - ETA: 0s - loss: 3.4318e-04 - mean_absolute_error: 0.0144
# Epoch 00024: val_loss improved from 0.00006 to 0.00003, saving model to results\2020-09-12_TSLA-huber_loss-adam-LSTM-seq-70-step-1-layers-3-units-256.h5
# 2000/2000 [==============================] - 4s 2ms/sample - loss: 3.4058e-04 - mean_absolute_error: 0.0143 - val_loss: 3.4030e-05 - val_mean_absolute_error: 0.0053
# Epoch 25/400
# 1984/2000 [============================>.] - ETA: 0s - loss: 2.0012e-04 - mean_absolute_error: 0.0114
# Epoch 00025: val_loss did not improve from 0.00003
# 2000/2000 [==============================] - 4s 2ms/sample - loss: 1.9887e-04 - mean_absolute_error: 0.0114 - val_loss: 7.6205e-05 - val_mean_absolute_error: 0.0081
# Epoch 26/400
# 1984/2000 [============================>.] - ETA: 0s - loss: 2.0812e-04 - mean_absolute_error: 0.0120
# Epoch 00026: val_loss improved from 0.00003 to 0.00003, saving model to results\2020-09-12_TSLA-huber_loss-adam-LSTM-seq-70-step-1-layers-3-units-256.h5
# 2000/2000 [==============================] - 4s 2ms/sample - loss: 2.0954e-04 - mean_absolute_error: 0.0121 - val_loss: 2.7536e-05 - val_mean_absolute_error: 0.0047
# Epoch 27/400
# 1984/2000 [============================>.] - ETA: 0s - loss: 1.9443e-04 - mean_absolute_error: 0.0117
# Epoch 00027: val_loss did not improve from 0.00003
# 2000/2000 [==============================] - 4s 2ms/sample - loss: 1.9326e-04 - mean_absolute_error: 0.0117 - val_loss: 4.9544e-05 - val_mean_absolute_error: 0.0075
# Epoch 28/400
# 1984/2000 [============================>.] - ETA: 0s - loss: 2.6988e-04 - mean_absolute_error: 0.0130
# Epoch 00028: val_loss did not improve from 0.00003
# 2000/2000 [==============================] - 4s 2ms/sample - loss: 2.7178e-04 - mean_absolute_error: 0.0130 - val_loss: 1.2339e-04 - val_mean_absolute_error: 0.0138
# Epoch 29/400
# 1984/2000 [============================>.] - ETA: 0s - loss: 2.3613e-04 - mean_absolute_error: 0.0128
# Epoch 00029: val_loss did not improve from 0.00003
# 2000/2000 [==============================] - 4s 2ms/sample - loss: 2.3529e-04 - mean_absolute_error: 0.0128 - val_loss: 6.8888e-05 - val_mean_absolute_error: 0.0060
# Epoch 30/400
# 1984/2000 [============================>.] - ETA: 0s - loss: 1.8611e-04 - mean_absolute_error: 0.0114
# Epoch 00030: val_loss did not improve from 0.00003
# 2000/2000 [==============================] - 4s 2ms/sample - loss: 1.8579e-04 - mean_absolute_error: 0.0114 - val_loss: 4.9061e-05 - val_mean_absolute_error: 0.0054
# Epoch 31/400
# 1984/2000 [============================>.] - ETA: 0s - loss: 2.3483e-04 - mean_absolute_error: 0.0123
# Epoch 00031: val_loss did not improve from 0.00003
# 2000/2000 [==============================] - 4s 2ms/sample - loss: 2.3383e-04 - mean_absolute_error: 0.0122 - val_loss: 6.3610e-05 - val_mean_absolute_error: 0.0073
# Epoch 32/400
# 1984/2000 [============================>.] - ETA: 0s - loss: 2.0413e-04 - mean_absolute_error: 0.0125
# Epoch 00032: val_loss did not improve from 0.00003
# 2000/2000 [==============================] - 4s 2ms/sample - loss: 2.0473e-04 - mean_absolute_error: 0.0125 - val_loss: 5.9793e-05 - val_mean_absolute_error: 0.0066
# Epoch 33/400
# 1984/2000 [============================>.] - ETA: 0s - loss: 1.4601e-04 - mean_absolute_error: 0.0102
# Epoch 00033: val_loss did not improve from 0.00003
# 2000/2000 [==============================] - 4s 2ms/sample - loss: 1.4713e-04 - mean_absolute_error: 0.0102 - val_loss: 3.4479e-05 - val_mean_absolute_error: 0.0052
# Epoch 34/400
# 1984/2000 [============================>.] - ETA: 0s - loss: 2.7705e-04 - mean_absolute_error: 0.0139
# Epoch 00034: val_loss did not improve from 0.00003
# 2000/2000 [==============================] - 5s 3ms/sample - loss: 2.7553e-04 - mean_absolute_error: 0.0138 - val_loss: 5.6807e-05 - val_mean_absolute_error: 0.0069
# Epoch 35/400
# 1984/2000 [============================>.] - ETA: 0s - loss: 2.2066e-04 - mean_absolute_error: 0.0123- ETA: 0s - loss: 2.2309e-04 - mean_absolute_error: 0.0
# Epoch 00035: val_loss did not improve from 0.00003
# 2000/2000 [==============================] - 6s 3ms/sample - loss: 2.2036e-04 - mean_absolute_error: 0.0123 - val_loss: 6.0716e-05 - val_mean_absolute_error: 0.0087
# Epoch 36/400
# 1984/2000 [============================>.] - ETA: 0s - loss: 1.7258e-04 - mean_absolute_error: 0.0105
# Epoch 00036: val_loss did not improve from 0.00003
# 2000/2000 [==============================] - 5s 2ms/sample - loss: 1.7272e-04 - mean_absolute_error: 0.0106 - val_loss: 4.0741e-05 - val_mean_absolute_error: 0.0054
# Epoch 37/400
# 1984/2000 [============================>.] - ETA: 0s - loss: 1.7988e-04 - mean_absolute_error: 0.0104
# Epoch 00037: val_loss did not improve from 0.00003
# 2000/2000 [==============================] - 5s 2ms/sample - loss: 1.7890e-04 - mean_absolute_error: 0.0104 - val_loss: 6.6461e-05 - val_mean_absolute_error: 0.0081
# Epoch 38/400
# 1984/2000 [============================>.] - ETA: 0s - loss: 1.9073e-04 - mean_absolute_error: 0.0126
# Epoch 00038: val_loss improved from 0.00003 to 0.00002, saving model to results\2020-09-12_TSLA-huber_loss-adam-LSTM-seq-70-step-1-layers-3-units-256.h5
# 2000/2000 [==============================] - 6s 3ms/sample - loss: 1.9027e-04 - mean_absolute_error: 0.0126 - val_loss: 1.9966e-05 - val_mean_absolute_error: 0.0042
# Epoch 39/400
# 1984/2000 [============================>.] - ETA: 0s - loss: 1.4209e-04 - mean_absolute_error: 0.0100
# Epoch 00039: val_loss did not improve from 0.00002
# 2000/2000 [==============================] - 6s 3ms/sample - loss: 1.4158e-04 - mean_absolute_error: 0.0100 - val_loss: 8.8350e-05 - val_mean_absolute_error: 0.0094
# Epoch 40/400
# 1984/2000 [============================>.] - ETA: 0s - loss: 2.0174e-04 - mean_absolute_error: 0.0115
# Epoch 00040: val_loss did not improve from 0.00002
# 2000/2000 [==============================] - 6s 3ms/sample - loss: 2.0040e-04 - mean_absolute_error: 0.0115 - val_loss: 4.0507e-05 - val_mean_absolute_error: 0.0068
# Epoch 41/400
# 1984/2000 [============================>.] - ETA: 0s - loss: 1.5702e-04 - mean_absolute_error: 0.0103
# Epoch 00041: val_loss did not improve from 0.00002
# 2000/2000 [==============================] - 5s 2ms/sample - loss: 1.5698e-04 - mean_absolute_error: 0.0103 - val_loss: 2.9417e-05 - val_mean_absolute_error: 0.0051
# Epoch 42/400
# 1984/2000 [============================>.] - ETA: 0s - loss: 1.4811e-04 - mean_absolute_error: 0.0099
# Epoch 00042: val_loss did not improve from 0.00002
# 2000/2000 [==============================] - 4s 2ms/sample - loss: 1.5359e-04 - mean_absolute_error: 0.0100 - val_loss: 6.8800e-05 - val_mean_absolute_error: 0.0087
# Epoch 43/400
# 1984/2000 [============================>.] - ETA: 0s - loss: 1.8573e-04 - mean_absolute_error: 0.0113
# Epoch 00043: val_loss did not improve from 0.00002
# 2000/2000 [==============================] - 4s 2ms/sample - loss: 1.8460e-04 - mean_absolute_error: 0.0113 - val_loss: 7.6602e-05 - val_mean_absolute_error: 0.0084
# Epoch 44/400
# 1984/2000 [============================>.] - ETA: 0s - loss: 1.6358e-04 - mean_absolute_error: 0.0106
# Epoch 00044: val_loss did not improve from 0.00002
# 2000/2000 [==============================] - 4s 2ms/sample - loss: 1.6281e-04 - mean_absolute_error: 0.0106 - val_loss: 5.4164e-05 - val_mean_absolute_error: 0.0073
# Epoch 45/400
# 1984/2000 [============================>.] - ETA: 0s - loss: 1.8480e-04 - mean_absolute_error: 0.0108
# Epoch 00045: val_loss did not improve from 0.00002
# 2000/2000 [==============================] - 4s 2ms/sample - loss: 1.8360e-04 - mean_absolute_error: 0.0108 - val_loss: 2.3251e-05 - val_mean_absolute_error: 0.0045
# Epoch 46/400
# 1984/2000 [============================>.] - ETA: 0s - loss: 1.4904e-04 - mean_absolute_error: 0.0099
# Epoch 00046: val_loss did not improve from 0.00002
# 2000/2000 [==============================] - 6s 3ms/sample - loss: 1.4821e-04 - mean_absolute_error: 0.0099 - val_loss: 2.7902e-05 - val_mean_absolute_error: 0.0039
# Epoch 47/400
# 1984/2000 [============================>.] - ETA: 0s - loss: 1.4285e-04 - mean_absolute_error: 0.0096
# Epoch 00047: val_loss did not improve from 0.00002
# 2000/2000 [==============================] - 6s 3ms/sample - loss: 1.4306e-04 - mean_absolute_error: 0.0096 - val_loss: 5.3175e-05 - val_mean_absolute_error: 0.0063
# Epoch 48/400
# 1984/2000 [============================>.] - ETA: 0s - loss: 1.4549e-04 - mean_absolute_error: 0.0097
# Epoch 00048: val_loss improved from 0.00002 to 0.00002, saving model to results\2020-09-12_TSLA-huber_loss-adam-LSTM-seq-70-step-1-layers-3-units-256.h5
# 2000/2000 [==============================] - 5s 3ms/sample - loss: 1.4632e-04 - mean_absolute_error: 0.0097 - val_loss: 1.7068e-05 - val_mean_absolute_error: 0.0034
# Epoch 49/400
# 1984/2000 [============================>.] - ETA: 0s - loss: 1.7070e-04 - mean_absolute_error: 0.0102
# Epoch 00049: val_loss did not improve from 0.00002
# 2000/2000 [==============================] - 5s 3ms/sample - loss: 1.7004e-04 - mean_absolute_error: 0.0102 - val_loss: 2.1114e-05 - val_mean_absolute_error: 0.0044
# Epoch 50/400
# 1984/2000 [============================>.] - ETA: 0s - loss: 1.3260e-04 - mean_absolute_error: 0.0104
# Epoch 00050: val_loss did not improve from 0.00002
# 2000/2000 [==============================] - 5s 2ms/sample - loss: 1.3276e-04 - mean_absolute_error: 0.0104 - val_loss: 3.8408e-05 - val_mean_absolute_error: 0.0063
# Epoch 51/400
# 1984/2000 [============================>.] - ETA: 0s - loss: 1.4799e-04 - mean_absolute_error: 0.0097
# Epoch 00051: val_loss did not improve from 0.00002
# 2000/2000 [==============================] - 4s 2ms/sample - loss: 1.4740e-04 - mean_absolute_error: 0.0097 - val_loss: 6.3711e-05 - val_mean_absolute_error: 0.0101
# Epoch 52/400
# 1984/2000 [============================>.] - ETA: 0s - loss: 1.8005e-04 - mean_absolute_error: 0.0104
# Epoch 00052: val_loss did not improve from 0.00002
# 2000/2000 [==============================] - 5s 3ms/sample - loss: 1.7905e-04 - mean_absolute_error: 0.0104 - val_loss: 4.5800e-05 - val_mean_absolute_error: 0.0067
# Epoch 53/400
# 1984/2000 [============================>.] - ETA: 0s - loss: 1.9667e-04 - mean_absolute_error: 0.0118
# Epoch 00053: val_loss did not improve from 0.00002
# 2000/2000 [==============================] - 5s 2ms/sample - loss: 1.9553e-04 - mean_absolute_error: 0.0117 - val_loss: 1.3463e-04 - val_mean_absolute_error: 0.0105
# Epoch 54/400
# 1984/2000 [============================>.] - ETA: 0s - loss: 1.6694e-04 - mean_absolute_error: 0.0108
# Epoch 00054: val_loss did not improve from 0.00002
# 2000/2000 [==============================] - 5s 3ms/sample - loss: 1.6762e-04 - mean_absolute_error: 0.0108 - val_loss: 2.6710e-05 - val_mean_absolute_error: 0.0040
# Epoch 55/400
# 1984/2000 [============================>.] - ETA: 0s - loss: 1.7588e-04 - mean_absolute_error: 0.0108
# Epoch 00055: val_loss did not improve from 0.00002
# 2000/2000 [==============================] - 4s 2ms/sample - loss: 1.7476e-04 - mean_absolute_error: 0.0108 - val_loss: 5.8679e-05 - val_mean_absolute_error: 0.0067
# Epoch 56/400
# 1984/2000 [============================>.] - ETA: 0s - loss: 1.3557e-04 - mean_absolute_error: 0.0095
# Epoch 00056: val_loss did not improve from 0.00002
# 2000/2000 [==============================] - 4s 2ms/sample - loss: 1.3481e-04 - mean_absolute_error: 0.0095 - val_loss: 3.6451e-05 - val_mean_absolute_error: 0.0057
# Epoch 57/400
# 1984/2000 [============================>.] - ETA: 0s - loss: 1.1949e-04 - mean_absolute_error: 0.0091
# Epoch 00057: val_loss did not improve from 0.00002
# 2000/2000 [==============================] - 4s 2ms/sample - loss: 1.2020e-04 - mean_absolute_error: 0.0091 - val_loss: 3.4452e-05 - val_mean_absolute_error: 0.0058
# Epoch 58/400
# 1984/2000 [============================>.] - ETA: 0s - loss: 1.1919e-04 - mean_absolute_error: 0.0092
# Epoch 00058: val_loss did not improve from 0.00002
# 2000/2000 [==============================] - 4s 2ms/sample - loss: 1.1835e-04 - mean_absolute_error: 0.0091 - val_loss: 3.2958e-05 - val_mean_absolute_error: 0.0053
# Epoch 59/400
# 1984/2000 [============================>.] - ETA: 0s - loss: 1.1558e-04 - mean_absolute_error: 0.0087
# Epoch 00059: val_loss did not improve from 0.00002
# 2000/2000 [==============================] - 4s 2ms/sample - loss: 1.1989e-04 - mean_absolute_error: 0.0088 - val_loss: 2.0163e-05 - val_mean_absolute_error: 0.0047
# Epoch 60/400
# 1984/2000 [============================>.] - ETA: 0s - loss: 1.4038e-04 - mean_absolute_error: 0.0098
# Epoch 00060: val_loss did not improve from 0.00002
# 2000/2000 [==============================] - 5s 3ms/sample - loss: 1.3967e-04 - mean_absolute_error: 0.0097 - val_loss: 2.2576e-05 - val_mean_absolute_error: 0.0047
# Epoch 61/400
# 1984/2000 [============================>.] - ETA: 0s - loss: 1.3463e-04 - mean_absolute_error: 0.0101
# Epoch 00061: val_loss did not improve from 0.00002
# 2000/2000 [==============================] - 5s 2ms/sample - loss: 1.3393e-04 - mean_absolute_error: 0.0100 - val_loss: 3.6206e-05 - val_mean_absolute_error: 0.0069
# Epoch 62/400
# 1984/2000 [============================>.] - ETA: 0s - loss: 1.4922e-04 - mean_absolute_error: 0.0095
# Epoch 00062: val_loss did not improve from 0.00002
# 2000/2000 [==============================] - 4s 2ms/sample - loss: 1.4933e-04 - mean_absolute_error: 0.0095 - val_loss: 2.2067e-05 - val_mean_absolute_error: 0.0044
# Epoch 63/400
# 1984/2000 [============================>.] - ETA: 0s - loss: 1.4622e-04 - mean_absolute_error: 0.0100
# Epoch 00063: val_loss did not improve from 0.00002
# 2000/2000 [==============================] - 4s 2ms/sample - loss: 1.4540e-04 - mean_absolute_error: 0.0100 - val_loss: 7.6432e-05 - val_mean_absolute_error: 0.0086
# Epoch 64/400
# 1984/2000 [============================>.] - ETA: 0s - loss: 1.4617e-04 - mean_absolute_error: 0.0097
# Epoch 00064: val_loss did not improve from 0.00002
# 2000/2000 [==============================] - 4s 2ms/sample - loss: 1.4533e-04 - mean_absolute_error: 0.0097 - val_loss: 2.3261e-05 - val_mean_absolute_error: 0.0051
# Epoch 65/400
# 1984/2000 [============================>.] - ETA: 0s - loss: 1.5003e-04 - mean_absolute_error: 0.0102
# Epoch 00065: val_loss did not improve from 0.00002
# 2000/2000 [==============================] - 4s 2ms/sample - loss: 1.4981e-04 - mean_absolute_error: 0.0102 - val_loss: 2.2542e-05 - val_mean_absolute_error: 0.0051
# Epoch 66/400
# 1984/2000 [============================>.] - ETA: 0s - loss: 1.3717e-04 - mean_absolute_error: 0.0098
# Epoch 00066: val_loss did not improve from 0.00002
# 2000/2000 [==============================] - 4s 2ms/sample - loss: 1.3855e-04 - mean_absolute_error: 0.0098 - val_loss: 3.8898e-05 - val_mean_absolute_error: 0.0070
# Epoch 67/400
# 1984/2000 [============================>.] - ETA: 0s - loss: 1.5861e-04 - mean_absolute_error: 0.0112
# Epoch 00067: val_loss did not improve from 0.00002
# 2000/2000 [==============================] - 5s 3ms/sample - loss: 1.5743e-04 - mean_absolute_error: 0.0112 - val_loss: 1.9792e-05 - val_mean_absolute_error: 0.0041
# Epoch 68/400
# 1984/2000 [============================>.] - ETA: 0s - loss: 1.6052e-04 - mean_absolute_error: 0.0097
# Epoch 00068: val_loss did not improve from 0.00002
# 2000/2000 [==============================] - 5s 2ms/sample - loss: 1.6062e-04 - mean_absolute_error: 0.0097 - val_loss: 4.7554e-05 - val_mean_absolute_error: 0.0076
# Epoch 69/400
# 1984/2000 [============================>.] - ETA: 0s - loss: 1.5148e-04 - mean_absolute_error: 0.0098
# Epoch 00069: val_loss did not improve from 0.00002
# 2000/2000 [==============================] - 4s 2ms/sample - loss: 1.5063e-04 - mean_absolute_error: 0.0098 - val_loss: 4.6168e-05 - val_mean_absolute_error: 0.0079
# Epoch 70/400
# 1984/2000 [============================>.] - ETA: 0s - loss: 1.4679e-04 - mean_absolute_error: 0.0102
# Epoch 00070: val_loss did not improve from 0.00002
# 2000/2000 [==============================] - 4s 2ms/sample - loss: 1.4607e-04 - mean_absolute_error: 0.0102 - val_loss: 1.7327e-05 - val_mean_absolute_error: 0.0036
# Epoch 71/400
# 1984/2000 [============================>.] - ETA: 0s - loss: 1.5498e-04 - mean_absolute_error: 0.0100
# Epoch 00071: val_loss did not improve from 0.00002
# 2000/2000 [==============================] - 5s 2ms/sample - loss: 1.5391e-04 - mean_absolute_error: 0.0099 - val_loss: 2.6262e-05 - val_mean_absolute_error: 0.0046
# Epoch 72/400
# 1984/2000 [============================>.] - ETA: 0s - loss: 1.1183e-04 - mean_absolute_error: 0.0091
# Epoch 00072: val_loss did not improve from 0.00002
# 2000/2000 [==============================] - 4s 2ms/sample - loss: 1.1189e-04 - mean_absolute_error: 0.0091 - val_loss: 4.1541e-05 - val_mean_absolute_error: 0.0059
# Epoch 73/400
# 1984/2000 [============================>.] - ETA: 0s - loss: 1.4952e-04 - mean_absolute_error: 0.0097
# Epoch 00073: val_loss did not improve from 0.00002
# 2000/2000 [==============================] - 5s 2ms/sample - loss: 1.4863e-04 - mean_absolute_error: 0.0097 - val_loss: 6.7139e-05 - val_mean_absolute_error: 0.0089
# Epoch 74/400
# 1984/2000 [============================>.] - ETA: 0s - loss: 1.6543e-04 - mean_absolute_error: 0.0107
# Epoch 00074: val_loss did not improve from 0.00002
# 2000/2000 [==============================] - 5s 2ms/sample - loss: 1.6464e-04 - mean_absolute_error: 0.0107 - val_loss: 7.4165e-05 - val_mean_absolute_error: 0.0100
# Epoch 75/400
# 1984/2000 [============================>.] - ETA: 0s - loss: 1.3201e-04 - mean_absolute_error: 0.0091
# Epoch 00075: val_loss did not improve from 0.00002
# 2000/2000 [==============================] - 4s 2ms/sample - loss: 1.3167e-04 - mean_absolute_error: 0.0091 - val_loss: 2.6662e-05 - val_mean_absolute_error: 0.0049
# Epoch 76/400
# 1984/2000 [============================>.] - ETA: 0s - loss: 1.2812e-04 - mean_absolute_error: 0.0094
# Epoch 00076: val_loss did not improve from 0.00002
# 2000/2000 [==============================] - 4s 2ms/sample - loss: 1.2854e-04 - mean_absolute_error: 0.0094 - val_loss: 2.7117e-05 - val_mean_absolute_error: 0.0053
# Epoch 77/400
# 1984/2000 [============================>.] - ETA: 0s - loss: 1.4052e-04 - mean_absolute_error: 0.0096
# Epoch 00077: val_loss did not improve from 0.00002
# 2000/2000 [==============================] - 4s 2ms/sample - loss: 1.3951e-04 - mean_absolute_error: 0.0096 - val_loss: 2.9285e-05 - val_mean_absolute_error: 0.0040
# Epoch 78/400
# 1984/2000 [============================>.] - ETA: 0s - loss: 1.3571e-04 - mean_absolute_error: 0.0091
# Epoch 00078: val_loss did not improve from 0.00002
# 2000/2000 [==============================] - 4s 2ms/sample - loss: 1.3681e-04 - mean_absolute_error: 0.0091 - val_loss: 3.1144e-05 - val_mean_absolute_error: 0.0050
# Epoch 79/400
# 1984/2000 [============================>.] - ETA: 0s - loss: 1.3635e-04 - mean_absolute_error: 0.0096
# Epoch 00079: val_loss did not improve from 0.00002
# 2000/2000 [==============================] - 4s 2ms/sample - loss: 1.3849e-04 - mean_absolute_error: 0.0096 - val_loss: 1.9902e-05 - val_mean_absolute_error: 0.0043
# Epoch 80/400
# 1984/2000 [============================>.] - ETA: 0s - loss: 1.6240e-04 - mean_absolute_error: 0.0101
# Epoch 00080: val_loss did not improve from 0.00002
# 2000/2000 [==============================] - 4s 2ms/sample - loss: 1.6307e-04 - mean_absolute_error: 0.0101 - val_loss: 3.5339e-05 - val_mean_absolute_error: 0.0049
# Epoch 81/400
# 1984/2000 [============================>.] - ETA: 0s - loss: 1.2797e-04 - mean_absolute_error: 0.0096
# Epoch 00081: val_loss did not improve from 0.00002
# 2000/2000 [==============================] - 4s 2ms/sample - loss: 1.3112e-04 - mean_absolute_error: 0.0097 - val_loss: 1.6651e-04 - val_mean_absolute_error: 0.0142
# Epoch 82/400
# 1984/2000 [============================>.] - ETA: 0s - loss: 2.2057e-04 - mean_absolute_error: 0.0138
# Epoch 00082: val_loss did not improve from 0.00002
# 2000/2000 [==============================] - 4s 2ms/sample - loss: 2.1933e-04 - mean_absolute_error: 0.0137 - val_loss: 2.6520e-05 - val_mean_absolute_error: 0.0051
# Epoch 83/400
# 1984/2000 [============================>.] - ETA: 0s - loss: 1.4556e-04 - mean_absolute_error: 0.0101
# Epoch 00083: val_loss did not improve from 0.00002
# 2000/2000 [==============================] - 4s 2ms/sample - loss: 1.4526e-04 - mean_absolute_error: 0.0101 - val_loss: 2.2701e-04 - val_mean_absolute_error: 0.0150
# Epoch 84/400
# 1984/2000 [============================>.] - ETA: 0s - loss: 2.1063e-04 - mean_absolute_error: 0.0129
# Epoch 00084: val_loss did not improve from 0.00002
# 2000/2000 [==============================] - 4s 2ms/sample - loss: 2.1266e-04 - mean_absolute_error: 0.0129 - val_loss: 2.0151e-05 - val_mean_absolute_error: 0.0043
# Epoch 85/400
# 1984/2000 [============================>.] - ETA: 0s - loss: 1.5294e-04 - mean_absolute_error: 0.0096
# Epoch 00085: val_loss did not improve from 0.00002
# 2000/2000 [==============================] - 4s 2ms/sample - loss: 1.5196e-04 - mean_absolute_error: 0.0096 - val_loss: 2.2188e-05 - val_mean_absolute_error: 0.0049
# Epoch 86/400
# 1984/2000 [============================>.] - ETA: 0s - loss: 1.1353e-04 - mean_absolute_error: 0.0088
# Epoch 00086: val_loss did not improve from 0.00002
# 2000/2000 [==============================] - 4s 2ms/sample - loss: 1.1299e-04 - mean_absolute_error: 0.0088 - val_loss: 1.7327e-05 - val_mean_absolute_error: 0.0040
# Epoch 87/400
# 1984/2000 [============================>.] - ETA: 0s - loss: 1.5209e-04 - mean_absolute_error: 0.0094
# Epoch 00087: val_loss did not improve from 0.00002
# 2000/2000 [==============================] - 4s 2ms/sample - loss: 1.5116e-04 - mean_absolute_error: 0.0094 - val_loss: 3.5662e-05 - val_mean_absolute_error: 0.0063
# Epoch 88/400
# 1984/2000 [============================>.] - ETA: 0s - loss: 1.0978e-04 - mean_absolute_error: 0.0094
# Epoch 00088: val_loss did not improve from 0.00002
# 2000/2000 [==============================] - 4s 2ms/sample - loss: 1.0929e-04 - mean_absolute_error: 0.0094 - val_loss: 5.3317e-05 - val_mean_absolute_error: 0.0058
# Epoch 89/400
# 1984/2000 [============================>.] - ETA: 0s - loss: 1.1353e-04 - mean_absolute_error: 0.0090
# Epoch 00089: val_loss did not improve from 0.00002
# 2000/2000 [==============================] - 4s 2ms/sample - loss: 1.1298e-04 - mean_absolute_error: 0.0089 - val_loss: 4.1037e-05 - val_mean_absolute_error: 0.0066
# Epoch 90/400
# 1984/2000 [============================>.] - ETA: 0s - loss: 1.2335e-04 - mean_absolute_error: 0.0092
# Epoch 00090: val_loss did not improve from 0.00002
# 2000/2000 [==============================] - 4s 2ms/sample - loss: 1.2402e-04 - mean_absolute_error: 0.0092 - val_loss: 2.3149e-05 - val_mean_absolute_error: 0.0049
# Epoch 91/400
# 1984/2000 [============================>.] - ETA: 0s - loss: 1.3408e-04 - mean_absolute_error: 0.0099
# Epoch 00091: val_loss did not improve from 0.00002
# 2000/2000 [==============================] - 4s 2ms/sample - loss: 1.3416e-04 - mean_absolute_error: 0.0099 - val_loss: 2.0468e-05 - val_mean_absolute_error: 0.0042
# Epoch 92/400
# 1984/2000 [============================>.] - ETA: 0s - loss: 1.8247e-04 - mean_absolute_error: 0.0104
# Epoch 00092: val_loss did not improve from 0.00002
# 2000/2000 [==============================] - 4s 2ms/sample - loss: 1.8144e-04 - mean_absolute_error: 0.0104 - val_loss: 2.6066e-05 - val_mean_absolute_error: 0.0054
# Epoch 93/400
# 1984/2000 [============================>.] - ETA: 0s - loss: 1.5001e-04 - mean_absolute_error: 0.0102
# Epoch 00093: val_loss did not improve from 0.00002
# 2000/2000 [==============================] - 4s 2ms/sample - loss: 1.4946e-04 - mean_absolute_error: 0.0102 - val_loss: 6.4208e-05 - val_mean_absolute_error: 0.0091
# Epoch 94/400
# 1984/2000 [============================>.] - ETA: 0s - loss: 1.5175e-04 - mean_absolute_error: 0.0112
# Epoch 00094: val_loss did not improve from 0.00002
# 2000/2000 [==============================] - 4s 2ms/sample - loss: 1.5071e-04 - mean_absolute_error: 0.0111 - val_loss: 4.7178e-05 - val_mean_absolute_error: 0.0070
# Epoch 95/400
# 1984/2000 [============================>.] - ETA: 0s - loss: 1.5341e-04 - mean_absolute_error: 0.0104
# Epoch 00095: val_loss did not improve from 0.00002
# 2000/2000 [==============================] - 4s 2ms/sample - loss: 1.5296e-04 - mean_absolute_error: 0.0104 - val_loss: 3.7232e-05 - val_mean_absolute_error: 0.0056
# Epoch 96/400
# 1984/2000 [============================>.] - ETA: 0s - loss: 1.0694e-04 - mean_absolute_error: 0.0085
# Epoch 00096: val_loss did not improve from 0.00002
# 2000/2000 [==============================] - 4s 2ms/sample - loss: 1.0622e-04 - mean_absolute_error: 0.0085 - val_loss: 1.8646e-05 - val_mean_absolute_error: 0.0043
# Epoch 97/400
# 1984/2000 [============================>.] - ETA: 0s - loss: 8.1919e-05 - mean_absolute_error: 0.0082
# Epoch 00097: val_loss did not improve from 0.00002
# 2000/2000 [==============================] - 4s 2ms/sample - loss: 8.3215e-05 - mean_absolute_error: 0.0083 - val_loss: 2.0593e-05 - val_mean_absolute_error: 0.0041
# Epoch 98/400
# 1984/2000 [============================>.] - ETA: 0s - loss: 1.0579e-04 - mean_absolute_error: 0.0083
# Epoch 00098: val_loss improved from 0.00002 to 0.00002, saving model to results\2020-09-12_TSLA-huber_loss-adam-LSTM-seq-70-step-1-layers-3-units-256.h5
# 2000/2000 [==============================] - 4s 2ms/sample - loss: 1.0817e-04 - mean_absolute_error: 0.0084 - val_loss: 1.6155e-05 - val_mean_absolute_error: 0.0031
# Epoch 99/400
# 1984/2000 [============================>.] - ETA: 0s - loss: 1.1502e-04 - mean_absolute_error: 0.0085
# Epoch 00099: val_loss did not improve from 0.00002
# 2000/2000 [==============================] - 5s 2ms/sample - loss: 1.1534e-04 - mean_absolute_error: 0.0085 - val_loss: 4.0458e-05 - val_mean_absolute_error: 0.0060
# Epoch 100/400
# 1984/2000 [============================>.] - ETA: 0s - loss: 1.1166e-04 - mean_absolute_error: 0.0088
# Epoch 00100: val_loss did not improve from 0.00002
# 2000/2000 [==============================] - 4s 2ms/sample - loss: 1.1187e-04 - mean_absolute_error: 0.0088 - val_loss: 2.0451e-05 - val_mean_absolute_error: 0.0049
# Epoch 101/400
# 1984/2000 [============================>.] - ETA: 0s - loss: 1.2635e-04 - mean_absolute_error: 0.0093
# Epoch 00101: val_loss did not improve from 0.00002
# 2000/2000 [==============================] - 4s 2ms/sample - loss: 1.2562e-04 - mean_absolute_error: 0.0093 - val_loss: 2.1474e-05 - val_mean_absolute_error: 0.0036
# Epoch 102/400
# 1984/2000 [============================>.] - ETA: 0s - loss: 1.3121e-04 - mean_absolute_error: 0.0091
# Epoch 00102: val_loss did not improve from 0.00002
# 2000/2000 [==============================] - 4s 2ms/sample - loss: 1.3066e-04 - mean_absolute_error: 0.0091 - val_loss: 5.9069e-05 - val_mean_absolute_error: 0.0064
# Epoch 103/400
# 1984/2000 [============================>.] - ETA: 0s - loss: 1.5622e-04 - mean_absolute_error: 0.0105
# Epoch 00103: val_loss did not improve from 0.00002
# 2000/2000 [==============================] - 4s 2ms/sample - loss: 1.5646e-04 - mean_absolute_error: 0.0105 - val_loss: 1.8702e-05 - val_mean_absolute_error: 0.0042
# Epoch 104/400
# 1984/2000 [============================>.] - ETA: 0s - loss: 1.4450e-04 - mean_absolute_error: 0.0101
# Epoch 00104: val_loss did not improve from 0.00002
# 2000/2000 [==============================] - 4s 2ms/sample - loss: 1.4349e-04 - mean_absolute_error: 0.0100 - val_loss: 1.8901e-05 - val_mean_absolute_error: 0.0040
# Epoch 105/400
# 1984/2000 [============================>.] - ETA: 0s - loss: 1.5008e-04 - mean_absolute_error: 0.0109
# Epoch 00105: val_loss did not improve from 0.00002
# 2000/2000 [==============================] - 5s 2ms/sample - loss: 1.5178e-04 - mean_absolute_error: 0.0109 - val_loss: 2.9988e-05 - val_mean_absolute_error: 0.0044
# Epoch 106/400
# 1984/2000 [============================>.] - ETA: 0s - loss: 1.9244e-04 - mean_absolute_error: 0.0122
# Epoch 00106: val_loss did not improve from 0.00002
# 2000/2000 [==============================] - 4s 2ms/sample - loss: 1.9121e-04 - mean_absolute_error: 0.0121 - val_loss: 4.4522e-05 - val_mean_absolute_error: 0.0080
# Epoch 107/400
# 1984/2000 [============================>.] - ETA: 0s - loss: 1.4125e-04 - mean_absolute_error: 0.0095
# Epoch 00107: val_loss did not improve from 0.00002
# 2000/2000 [==============================] - 4s 2ms/sample - loss: 1.4046e-04 - mean_absolute_error: 0.0095 - val_loss: 4.2909e-05 - val_mean_absolute_error: 0.0079
# Epoch 108/400
# 1984/2000 [============================>.] - ETA: 0s - loss: 1.4511e-04 - mean_absolute_error: 0.0099
# Epoch 00108: val_loss did not improve from 0.00002
# 2000/2000 [==============================] - 4s 2ms/sample - loss: 1.4460e-04 - mean_absolute_error: 0.0099 - val_loss: 4.4239e-05 - val_mean_absolute_error: 0.0056
# Epoch 109/400
# 1984/2000 [============================>.] - ETA: 0s - loss: 1.3191e-04 - mean_absolute_error: 0.0087
# Epoch 00109: val_loss did not improve from 0.00002
# 2000/2000 [==============================] - 4s 2ms/sample - loss: 1.3164e-04 - mean_absolute_error: 0.0087 - val_loss: 1.3376e-04 - val_mean_absolute_error: 0.0106
# Epoch 110/400
# 1984/2000 [============================>.] - ETA: 0s - loss: 1.8073e-04 - mean_absolute_error: 0.0113
# Epoch 00110: val_loss improved from 0.00002 to 0.00002, saving model to results\2020-09-12_TSLA-huber_loss-adam-LSTM-seq-70-step-1-layers-3-units-256.h5
# 2000/2000 [==============================] - 5s 2ms/sample - loss: 1.8058e-04 - mean_absolute_error: 0.0113 - val_loss: 1.5411e-05 - val_mean_absolute_error: 0.0031
# Epoch 111/400
# 1984/2000 [============================>.] - ETA: 0s - loss: 9.7471e-05 - mean_absolute_error: 0.0082
# Epoch 00111: val_loss improved from 0.00002 to 0.00001, saving model to results\2020-09-12_TSLA-huber_loss-adam-LSTM-seq-70-step-1-layers-3-units-256.h5
# 2000/2000 [==============================] - 5s 2ms/sample - loss: 9.6850e-05 - mean_absolute_error: 0.0082 - val_loss: 1.3782e-05 - val_mean_absolute_error: 0.0032
# Epoch 112/400
# 1984/2000 [============================>.] - ETA: 0s - loss: 1.3907e-04 - mean_absolute_error: 0.0091
# Epoch 00112: val_loss did not improve from 0.00001
# 2000/2000 [==============================] - 5s 2ms/sample - loss: 1.3821e-04 - mean_absolute_error: 0.0091 - val_loss: 4.5994e-05 - val_mean_absolute_error: 0.0050
# Epoch 113/400
# 1984/2000 [============================>.] - ETA: 0s - loss: 1.3151e-04 - mean_absolute_error: 0.0091
# Epoch 00113: val_loss did not improve from 0.00001
# 2000/2000 [==============================] - 5s 2ms/sample - loss: 1.3096e-04 - mean_absolute_error: 0.0091 - val_loss: 3.4783e-05 - val_mean_absolute_error: 0.0050
# Epoch 114/400
# 1984/2000 [============================>.] - ETA: 0s - loss: 1.0996e-04 - mean_absolute_error: 0.0086
# Epoch 00114: val_loss did not improve from 0.00001
# 2000/2000 [==============================] - 5s 2ms/sample - loss: 1.1201e-04 - mean_absolute_error: 0.0086 - val_loss: 1.8364e-05 - val_mean_absolute_error: 0.0042
# Epoch 115/400
# 1984/2000 [============================>.] - ETA: 0s - loss: 1.5760e-04 - mean_absolute_error: 0.0099
# Epoch 00115: val_loss did not improve from 0.00001
# 2000/2000 [==============================] - 4s 2ms/sample - loss: 1.5788e-04 - mean_absolute_error: 0.0099 - val_loss: 2.3201e-05 - val_mean_absolute_error: 0.0049
# Epoch 116/400
# 1984/2000 [============================>.] - ETA: 0s - loss: 1.0098e-04 - mean_absolute_error: 0.0085
# Epoch 00116: val_loss did not improve from 0.00001
# 2000/2000 [==============================] - 5s 2ms/sample - loss: 1.0084e-04 - mean_absolute_error: 0.0085 - val_loss: 2.4067e-05 - val_mean_absolute_error: 0.0048
# Epoch 117/400
# 1984/2000 [============================>.] - ETA: 0s - loss: 1.5914e-04 - mean_absolute_error: 0.0101
# Epoch 00117: val_loss did not improve from 0.00001
# 2000/2000 [==============================] - 4s 2ms/sample - loss: 1.5914e-04 - mean_absolute_error: 0.0101 - val_loss: 2.3163e-05 - val_mean_absolute_error: 0.0051
# Epoch 118/400
# 1984/2000 [============================>.] - ETA: 0s - loss: 1.1728e-04 - mean_absolute_error: 0.0089
# Epoch 00118: val_loss did not improve from 0.00001
# 2000/2000 [==============================] - 4s 2ms/sample - loss: 1.1675e-04 - mean_absolute_error: 0.0089 - val_loss: 1.3789e-05 - val_mean_absolute_error: 0.0034
# Epoch 119/400
# 1984/2000 [============================>.] - ETA: 0s - loss: 9.3892e-05 - mean_absolute_error: 0.0084
# Epoch 00119: val_loss did not improve from 0.00001
# 2000/2000 [==============================] - 4s 2ms/sample - loss: 9.3473e-05 - mean_absolute_error: 0.0084 - val_loss: 3.6947e-05 - val_mean_absolute_error: 0.0054
# Epoch 120/400
# 1984/2000 [============================>.] - ETA: 0s - loss: 1.4723e-04 - mean_absolute_error: 0.0097
# Epoch 00120: val_loss did not improve from 0.00001
# 2000/2000 [==============================] - 4s 2ms/sample - loss: 1.4660e-04 - mean_absolute_error: 0.0097 - val_loss: 3.7710e-05 - val_mean_absolute_error: 0.0063
# Epoch 121/400
# 1984/2000 [============================>.] - ETA: 0s - loss: 9.6825e-05 - mean_absolute_error: 0.0086
# Epoch 00121: val_loss did not improve from 0.00001
# 2000/2000 [==============================] - 4s 2ms/sample - loss: 9.8776e-05 - mean_absolute_error: 0.0086 - val_loss: 3.4186e-05 - val_mean_absolute_error: 0.0058
# Epoch 122/400
# 1984/2000 [============================>.] - ETA: 0s - loss: 1.1873e-04 - mean_absolute_error: 0.0091
# Epoch 00122: val_loss did not improve from 0.00001
# 2000/2000 [==============================] - 4s 2ms/sample - loss: 1.1803e-04 - mean_absolute_error: 0.0091 - val_loss: 5.1588e-05 - val_mean_absolute_error: 0.0079
# Epoch 123/400
# 1984/2000 [============================>.] - ETA: 0s - loss: 9.7950e-05 - mean_absolute_error: 0.0087
# Epoch 00123: val_loss did not improve from 0.00001
# 2000/2000 [==============================] - 4s 2ms/sample - loss: 9.7770e-05 - mean_absolute_error: 0.0087 - val_loss: 3.7034e-05 - val_mean_absolute_error: 0.0053
# Epoch 124/400
# 1984/2000 [============================>.] - ETA: 0s - loss: 1.1111e-04 - mean_absolute_error: 0.0093
# Epoch 00124: val_loss did not improve from 0.00001
# 2000/2000 [==============================] - 4s 2ms/sample - loss: 1.1066e-04 - mean_absolute_error: 0.0093 - val_loss: 6.6730e-05 - val_mean_absolute_error: 0.0064
# Epoch 125/400
# 1984/2000 [============================>.] - ETA: 0s - loss: 1.3891e-04 - mean_absolute_error: 0.0093
# Epoch 00125: val_loss did not improve from 0.00001
# 2000/2000 [==============================] - 5s 2ms/sample - loss: 1.3854e-04 - mean_absolute_error: 0.0093 - val_loss: 3.8691e-05 - val_mean_absolute_error: 0.0056
# Epoch 126/400
# 1984/2000 [============================>.] - ETA: 0s - loss: 1.2004e-04 - mean_absolute_error: 0.0100
# Epoch 00126: val_loss did not improve from 0.00001
# 2000/2000 [==============================] - 4s 2ms/sample - loss: 1.1933e-04 - mean_absolute_error: 0.0099 - val_loss: 4.7091e-05 - val_mean_absolute_error: 0.0070
# Epoch 127/400
# 1984/2000 [============================>.] - ETA: 0s - loss: 1.2714e-04 - mean_absolute_error: 0.0091
# Epoch 00127: val_loss did not improve from 0.00001
# 2000/2000 [==============================] - 4s 2ms/sample - loss: 1.2735e-04 - mean_absolute_error: 0.0091 - val_loss: 1.7270e-05 - val_mean_absolute_error: 0.0039
# Epoch 128/400
# 1984/2000 [============================>.] - ETA: 0s - loss: 1.2542e-04 - mean_absolute_error: 0.0092
# Epoch 00128: val_loss did not improve from 0.00001
# 2000/2000 [==============================] - 4s 2ms/sample - loss: 1.2505e-04 - mean_absolute_error: 0.0092 - val_loss: 8.4382e-05 - val_mean_absolute_error: 0.0094
# Epoch 129/400
# 1984/2000 [============================>.] - ETA: 0s - loss: 1.5408e-04 - mean_absolute_error: 0.0099
# Epoch 00129: val_loss did not improve from 0.00001
# 2000/2000 [==============================] - 4s 2ms/sample - loss: 1.5416e-04 - mean_absolute_error: 0.0100 - val_loss: 3.6477e-05 - val_mean_absolute_error: 0.0066
# Epoch 130/400
# 1984/2000 [============================>.] - ETA: 0s - loss: 1.3412e-04 - mean_absolute_error: 0.0102
# Epoch 00130: val_loss did not improve from 0.00001
# 2000/2000 [==============================] - 4s 2ms/sample - loss: 1.3402e-04 - mean_absolute_error: 0.0102 - val_loss: 5.1596e-05 - val_mean_absolute_error: 0.0066
# Epoch 131/400
# 1984/2000 [============================>.] - ETA: 0s - loss: 1.5697e-04 - mean_absolute_error: 0.0099
# Epoch 00131: val_loss did not improve from 0.00001
# 2000/2000 [==============================] - 5s 2ms/sample - loss: 1.5913e-04 - mean_absolute_error: 0.0099 - val_loss: 2.8015e-05 - val_mean_absolute_error: 0.0048
# Epoch 132/400
# 1984/2000 [============================>.] - ETA: 0s - loss: 1.3701e-04 - mean_absolute_error: 0.0098
# Epoch 00132: val_loss did not improve from 0.00001
# 2000/2000 [==============================] - 4s 2ms/sample - loss: 1.3719e-04 - mean_absolute_error: 0.0099 - val_loss: 2.1107e-05 - val_mean_absolute_error: 0.0046
# Epoch 133/400
# 1984/2000 [============================>.] - ETA: 0s - loss: 1.5088e-04 - mean_absolute_error: 0.0092
# Epoch 00133: val_loss did not improve from 0.00001
# 2000/2000 [==============================] - 4s 2ms/sample - loss: 1.5240e-04 - mean_absolute_error: 0.0093 - val_loss: 7.0117e-05 - val_mean_absolute_error: 0.0094
# Epoch 134/400
# 1984/2000 [============================>.] - ETA: 0s - loss: 1.3595e-04 - mean_absolute_error: 0.0110
# Epoch 00134: val_loss did not improve from 0.00001
# 2000/2000 [==============================] - 4s 2ms/sample - loss: 1.3549e-04 - mean_absolute_error: 0.0110 - val_loss: 3.8689e-05 - val_mean_absolute_error: 0.0068
# Epoch 135/400
# 1984/2000 [============================>.] - ETA: 0s - loss: 1.1022e-04 - mean_absolute_error: 0.0091
# Epoch 00135: val_loss did not improve from 0.00001
# 2000/2000 [==============================] - 4s 2ms/sample - loss: 1.0944e-04 - mean_absolute_error: 0.0090 - val_loss: 3.1426e-05 - val_mean_absolute_error: 0.0055
# Epoch 136/400
# 1984/2000 [============================>.] - ETA: 0s - loss: 1.0439e-04 - mean_absolute_error: 0.0079
# Epoch 00136: val_loss did not improve from 0.00001
# 2000/2000 [==============================] - 4s 2ms/sample - loss: 1.0616e-04 - mean_absolute_error: 0.0079 - val_loss: 5.4165e-05 - val_mean_absolute_error: 0.0076
# Epoch 137/400
# 1984/2000 [============================>.] - ETA: 0s - loss: 1.2887e-04 - mean_absolute_error: 0.0093
# Epoch 00137: val_loss did not improve from 0.00001
# 2000/2000 [==============================] - 4s 2ms/sample - loss: 1.2959e-04 - mean_absolute_error: 0.0093 - val_loss: 1.8078e-05 - val_mean_absolute_error: 0.0036
# Epoch 138/400
# 1984/2000 [============================>.] - ETA: 0s - loss: 1.0793e-04 - mean_absolute_error: 0.0086
# Epoch 00138: val_loss did not improve from 0.00001
# 2000/2000 [==============================] - 4s 2ms/sample - loss: 1.0716e-04 - mean_absolute_error: 0.0086 - val_loss: 2.0469e-05 - val_mean_absolute_error: 0.0043
# Epoch 139/400
# 1984/2000 [============================>.] - ETA: 0s - loss: 9.8217e-05 - mean_absolute_error: 0.0082
# Epoch 00139: val_loss did not improve from 0.00001
# 2000/2000 [==============================] - 4s 2ms/sample - loss: 9.7994e-05 - mean_absolute_error: 0.0082 - val_loss: 3.5063e-05 - val_mean_absolute_error: 0.0059
# Epoch 140/400
# ...
# Epoch 00353: val_loss did not improve from 0.00001
# 2000/2000 [==============================] - 4s 2ms/sample - loss: 8.4449e-05 - mean_absolute_error: 0.0075 - val_loss: 3.4545e-05 - val_mean_absolute_error: 0.0059
# Epoch 354/400
# 1984/2000 [============================>.] - ETA: 0s - loss: 7.3984e-05 - mean_absolute_error: 0.0071
# Epoch 00354: val_loss did not improve from 0.00001
# 2000/2000 [==============================] - 4s 2ms/sample - loss: 7.4091e-05 - mean_absolute_error: 0.0072 - val_loss: 3.1895e-05 - val_mean_absolute_error: 0.0052
# Epoch 355/400
# 1984/2000 [============================>.] - ETA: 0s - loss: 1.1036e-04 - mean_absolute_error: 0.0081
# Epoch 00355: val_loss did not improve from 0.00001
# 2000/2000 [==============================] - 4s 2ms/sample - loss: 1.0968e-04 - mean_absolute_error: 0.0080 - val_loss: 1.5292e-05 - val_mean_absolute_error: 0.0037
# Epoch 356/400
# 1984/2000 [============================>.] - ETA: 0s - loss: 6.9282e-05 - mean_absolute_error: 0.0067
# Epoch 00356: val_loss did not improve from 0.00001
# 2000/2000 [==============================] - 4s 2ms/sample - loss: 6.9107e-05 - mean_absolute_error: 0.0067 - val_loss: 1.5392e-05 - val_mean_absolute_error: 0.0037
# Epoch 357/400
# 1984/2000 [============================>.] - ETA: 0s - loss: 7.5850e-05 - mean_absolute_error: 0.0072
# Epoch 00357: val_loss did not improve from 0.00001
# 2000/2000 [==============================] - 4s 2ms/sample - loss: 7.5881e-05 - mean_absolute_error: 0.0072 - val_loss: 4.2851e-05 - val_mean_absolute_error: 0.0060
# Epoch 358/400
# 1984/2000 [============================>.] - ETA: 0s - loss: 7.8083e-05 - mean_absolute_error: 0.0070
# Epoch 00358: val_loss did not improve from 0.00001
# 2000/2000 [==============================] - 4s 2ms/sample - loss: 7.7837e-05 - mean_absolute_error: 0.0070 - val_loss: 1.8249e-05 - val_mean_absolute_error: 0.0036
# Epoch 359/400
# 1984/2000 [============================>.] - ETA: 0s - loss: 6.0483e-05 - mean_absolute_error: 0.0066
# Epoch 00359: val_loss did not improve from 0.00001
# 2000/2000 [==============================] - 4s 2ms/sample - loss: 6.0248e-05 - mean_absolute_error: 0.0066 - val_loss: 1.8517e-05 - val_mean_absolute_error: 0.0044
# Epoch 360/400
# 1984/2000 [============================>.] - ETA: 0s - loss: 7.3110e-05 - mean_absolute_error: 0.0071
# Epoch 00360: val_loss did not improve from 0.00001
# 2000/2000 [==============================] - 4s 2ms/sample - loss: 7.2711e-05 - mean_absolute_error: 0.0071 - val_loss: 1.6916e-05 - val_mean_absolute_error: 0.0039
# Epoch 361/400
# 1984/2000 [============================>.] - ETA: 0s - loss: 8.5595e-05 - mean_absolute_error: 0.0072
# Epoch 00361: val_loss did not improve from 0.00001
# 2000/2000 [==============================] - 4s 2ms/sample - loss: 8.5325e-05 - mean_absolute_error: 0.0072 - val_loss: 2.4768e-05 - val_mean_absolute_error: 0.0045
# Epoch 362/400
# 1984/2000 [============================>.] - ETA: 0s - loss: 8.1629e-05 - mean_absolute_error: 0.0075
# Epoch 00362: val_loss did not improve from 0.00001
# 2000/2000 [==============================] - 4s 2ms/sample - loss: 8.1215e-05 - mean_absolute_error: 0.0075 - val_loss: 2.3158e-05 - val_mean_absolute_error: 0.0045
# Epoch 363/400
# 1984/2000 [============================>.] - ETA: 0s - loss: 7.0960e-05 - mean_absolute_error: 0.0068
# Epoch 00363: val_loss did not improve from 0.00001
# 2000/2000 [==============================] - 4s 2ms/sample - loss: 7.0770e-05 - mean_absolute_error: 0.0067 - val_loss: 2.3856e-05 - val_mean_absolute_error: 0.0046
# Epoch 364/400
# 1984/2000 [============================>.] - ETA: 0s - loss: 8.0686e-05 - mean_absolute_error: 0.0074
# Epoch 00364: val_loss did not improve from 0.00001
# 2000/2000 [==============================] - 4s 2ms/sample - loss: 8.1539e-05 - mean_absolute_error: 0.0075 - val_loss: 2.4624e-05 - val_mean_absolute_error: 0.0052
# Epoch 365/400
# 1984/2000 [============================>.] - ETA: 0s - loss: 7.1090e-05 - mean_absolute_error: 0.0068
# Epoch 00365: val_loss did not improve from 0.00001
# 2000/2000 [==============================] - 4s 2ms/sample - loss: 7.0802e-05 - mean_absolute_error: 0.0068 - val_loss: 1.8061e-05 - val_mean_absolute_error: 0.0040
# Epoch 366/400
# 1984/2000 [============================>.] - ETA: 0s - loss: 7.5739e-05 - mean_absolute_error: 0.0073
# Epoch 00366: val_loss did not improve from 0.00001
# 2000/2000 [==============================] - 4s 2ms/sample - loss: 7.5426e-05 - mean_absolute_error: 0.0073 - val_loss: 1.4576e-05 - val_mean_absolute_error: 0.0036
# Epoch 367/400
# 1984/2000 [============================>.] - ETA: 0s - loss: 1.0322e-04 - mean_absolute_error: 0.0084
# Epoch 00367: val_loss did not improve from 0.00001
# 2000/2000 [==============================] - 6s 3ms/sample - loss: 1.0271e-04 - mean_absolute_error: 0.0083 - val_loss: 4.6169e-05 - val_mean_absolute_error: 0.0068
# Epoch 368/400
# 1984/2000 [============================>.] - ETA: 0s - loss: 6.4151e-05 - mean_absolute_error: 0.0071
# Epoch 00368: val_loss did not improve from 0.00001
# 2000/2000 [==============================] - 4s 2ms/sample - loss: 6.3861e-05 - mean_absolute_error: 0.0071 - val_loss: 2.3284e-05 - val_mean_absolute_error: 0.0037
# Epoch 369/400
# 1984/2000 [============================>.] - ETA: 0s - loss: 1.0453e-04 - mean_absolute_error: 0.0079
# Epoch 00369: val_loss did not improve from 0.00001
# 2000/2000 [==============================] - 4s 2ms/sample - loss: 1.0416e-04 - mean_absolute_error: 0.0079 - val_loss: 1.7245e-05 - val_mean_absolute_error: 0.0032
# Epoch 370/400
# 1984/2000 [============================>.] - ETA: 0s - loss: 8.0186e-05 - mean_absolute_error: 0.0076
# Epoch 00370: val_loss did not improve from 0.00001
# 2000/2000 [==============================] - 4s 2ms/sample - loss: 7.9887e-05 - mean_absolute_error: 0.0075 - val_loss: 2.8944e-05 - val_mean_absolute_error: 0.0038
# Epoch 371/400
# 1984/2000 [============================>.] - ETA: 0s - loss: 9.1798e-05 - mean_absolute_error: 0.0074
# Epoch 00371: val_loss did not improve from 0.00001
# 2000/2000 [==============================] - 4s 2ms/sample - loss: 9.1232e-05 - mean_absolute_error: 0.0074 - val_loss: 2.0633e-05 - val_mean_absolute_error: 0.0044
# Epoch 372/400
# 1984/2000 [============================>.] - ETA: 0s - loss: 9.7203e-05 - mean_absolute_error: 0.0078
# Epoch 00372: val_loss did not improve from 0.00001
# 2000/2000 [==============================] - 4s 2ms/sample - loss: 9.6967e-05 - mean_absolute_error: 0.0078 - val_loss: 4.0096e-05 - val_mean_absolute_error: 0.0067
# Epoch 373/400
# 1984/2000 [============================>.] - ETA: 0s - loss: 1.0090e-04 - mean_absolute_error: 0.0082
# Epoch 00373: val_loss did not improve from 0.00001
# 2000/2000 [==============================] - 4s 2ms/sample - loss: 1.0327e-04 - mean_absolute_error: 0.0083 - val_loss: 2.7300e-05 - val_mean_absolute_error: 0.0052
# Epoch 374/400
# 1984/2000 [============================>.] - ETA: 0s - loss: 1.1552e-04 - mean_absolute_error: 0.0080
# Epoch 00374: val_loss did not improve from 0.00001
# 2000/2000 [==============================] - 4s 2ms/sample - loss: 1.1485e-04 - mean_absolute_error: 0.0080 - val_loss: 3.0713e-05 - val_mean_absolute_error: 0.0046
# Epoch 375/400
# 1984/2000 [============================>.] - ETA: 0s - loss: 8.2072e-05 - mean_absolute_error: 0.0077
# Epoch 00375: val_loss did not improve from 0.00001
# 2000/2000 [==============================] - 4s 2ms/sample - loss: 8.1834e-05 - mean_absolute_error: 0.0077 - val_loss: 3.6735e-05 - val_mean_absolute_error: 0.0051
# Epoch 376/400
# 1984/2000 [============================>.] - ETA: 0s - loss: 7.1707e-05 - mean_absolute_error: 0.0073
# Epoch 00376: val_loss did not improve from 0.00001
# 2000/2000 [==============================] - 4s 2ms/sample - loss: 7.1341e-05 - mean_absolute_error: 0.0073 - val_loss: 2.2076e-05 - val_mean_absolute_error: 0.0036
# Epoch 377/400
# 1984/2000 [============================>.] - ETA: 0s - loss: 8.7156e-05 - mean_absolute_error: 0.0076
# Epoch 00377: val_loss did not improve from 0.00001
# 2000/2000 [==============================] - 4s 2ms/sample - loss: 8.6740e-05 - mean_absolute_error: 0.0076 - val_loss: 4.1266e-05 - val_mean_absolute_error: 0.0057
# Epoch 378/400
# 1984/2000 [============================>.] - ETA: 0s - loss: 1.2505e-04 - mean_absolute_error: 0.0092
# Epoch 00378: val_loss did not improve from 0.00001
# 2000/2000 [==============================] - 4s 2ms/sample - loss: 1.2422e-04 - mean_absolute_error: 0.0092 - val_loss: 4.3621e-05 - val_mean_absolute_error: 0.0062
# Epoch 379/400
# 1984/2000 [============================>.] - ETA: 0s - loss: 8.9443e-05 - mean_absolute_error: 0.0086
# Epoch 00379: val_loss improved from 0.00001 to 0.00001, saving model to results\2020-09-12_TSLA-huber_loss-adam-LSTM-seq-70-step-1-layers-3-units-256.h5
# 2000/2000 [==============================] - 4s 2ms/sample - loss: 8.8836e-05 - mean_absolute_error: 0.0086 - val_loss: 1.2997e-05 - val_mean_absolute_error: 0.0030
# Epoch 380/400
# 1984/2000 [============================>.] - ETA: 0s - loss: 6.4441e-05 - mean_absolute_error: 0.0071
# Epoch 00380: val_loss did not improve from 0.00001
# 2000/2000 [==============================] - 4s 2ms/sample - loss: 6.4150e-05 - mean_absolute_error: 0.0071 - val_loss: 1.7592e-05 - val_mean_absolute_error: 0.0040
# Epoch 381/400
# 1984/2000 [============================>.] - ETA: 0s - loss: 7.6694e-05 - mean_absolute_error: 0.0069
# Epoch 00381: val_loss did not improve from 0.00001
# 2000/2000 [==============================] - 4s 2ms/sample - loss: 7.6918e-05 - mean_absolute_error: 0.0069 - val_loss: 1.6986e-05 - val_mean_absolute_error: 0.0038
# Epoch 382/400
# 1984/2000 [============================>.] - ETA: 0s - loss: 8.6882e-05 - mean_absolute_error: 0.0073
# Epoch 00382: val_loss did not improve from 0.00001
# 2000/2000 [==============================] - 4s 2ms/sample - loss: 8.6316e-05 - mean_absolute_error: 0.0073 - val_loss: 2.0928e-05 - val_mean_absolute_error: 0.0038
# Epoch 383/400
# 1984/2000 [============================>.] - ETA: 0s - loss: 6.6032e-05 - mean_absolute_error: 0.0069
# Epoch 00383: val_loss did not improve from 0.00001
# 2000/2000 [==============================] - 4s 2ms/sample - loss: 6.5675e-05 - mean_absolute_error: 0.0068 - val_loss: 1.6440e-05 - val_mean_absolute_error: 0.0038
# Epoch 384/400
# 1984/2000 [============================>.] - ETA: 0s - loss: 1.0312e-04 - mean_absolute_error: 0.0084
# Epoch 00384: val_loss did not improve from 0.00001
# 2000/2000 [==============================] - 4s 2ms/sample - loss: 1.0268e-04 - mean_absolute_error: 0.0083 - val_loss: 4.3077e-05 - val_mean_absolute_error: 0.0069
# Epoch 385/400
# 1984/2000 [============================>.] - ETA: 0s - loss: 9.8078e-05 - mean_absolute_error: 0.0080
# Epoch 00385: val_loss did not improve from 0.00001
# 2000/2000 [==============================] - 4s 2ms/sample - loss: 9.7742e-05 - mean_absolute_error: 0.0080 - val_loss: 2.3799e-05 - val_mean_absolute_error: 0.0048
# Epoch 386/400
# 1984/2000 [============================>.] - ETA: 0s - loss: 1.3276e-04 - mean_absolute_error: 0.0095
# Epoch 00386: val_loss did not improve from 0.00001
# 2000/2000 [==============================] - 4s 2ms/sample - loss: 1.3193e-04 - mean_absolute_error: 0.0095 - val_loss: 5.7355e-05 - val_mean_absolute_error: 0.0077
# Epoch 387/400
# 1984/2000 [============================>.] - ETA: 0s - loss: 1.6966e-04 - mean_absolute_error: 0.0099
# Epoch 00387: val_loss did not improve from 0.00001
# 2000/2000 [==============================] - 4s 2ms/sample - loss: 1.6874e-04 - mean_absolute_error: 0.0098 - val_loss: 4.8110e-05 - val_mean_absolute_error: 0.0072
# Epoch 388/400
# 1984/2000 [============================>.] - ETA: 0s - loss: 9.3942e-05 - mean_absolute_error: 0.0082
# Epoch 00388: val_loss did not improve from 0.00001
# 2000/2000 [==============================] - 4s 2ms/sample - loss: 9.3393e-05 - mean_absolute_error: 0.0082 - val_loss: 2.4170e-05 - val_mean_absolute_error: 0.0043
# Epoch 389/400
# 1984/2000 [============================>.] - ETA: 0s - loss: 8.2128e-05 - mean_absolute_error: 0.0075
# Epoch 00389: val_loss did not improve from 0.00001
# 2000/2000 [==============================] - 4s 2ms/sample - loss: 8.3412e-05 - mean_absolute_error: 0.0075 - val_loss: 2.7756e-05 - val_mean_absolute_error: 0.0055
# Epoch 390/400
# 1984/2000 [============================>.] - ETA: 0s - loss: 9.1145e-05 - mean_absolute_error: 0.0079
# Epoch 00390: val_loss did not improve from 0.00001
# 2000/2000 [==============================] - 4s 2ms/sample - loss: 9.0609e-05 - mean_absolute_error: 0.0079 - val_loss: 5.6708e-05 - val_mean_absolute_error: 0.0081
# Epoch 391/400
# 1984/2000 [============================>.] - ETA: 0s - loss: 7.7499e-05 - mean_absolute_error: 0.0075
# Epoch 00391: val_loss did not improve from 0.00001
# 2000/2000 [==============================] - 4s 2ms/sample - loss: 7.8962e-05 - mean_absolute_error: 0.0075 - val_loss: 2.0463e-05 - val_mean_absolute_error: 0.0047
# Epoch 392/400
# 1984/2000 [============================>.] - ETA: 0s - loss: 7.9122e-05 - mean_absolute_error: 0.0074
# Epoch 00392: val_loss did not improve from 0.00001
# 2000/2000 [==============================] - 4s 2ms/sample - loss: 7.8695e-05 - mean_absolute_error: 0.0074 - val_loss: 2.1599e-05 - val_mean_absolute_error: 0.0040
# Epoch 393/400
# 1984/2000 [============================>.] - ETA: 0s - loss: 7.2761e-05 - mean_absolute_error: 0.0072
# Epoch 00393: val_loss did not improve from 0.00001
# 2000/2000 [==============================] - 4s 2ms/sample - loss: 7.2351e-05 - mean_absolute_error: 0.0072 - val_loss: 1.4702e-05 - val_mean_absolute_error: 0.0032
# Epoch 394/400
# 1984/2000 [============================>.] - ETA: 0s - loss: 1.1168e-04 - mean_absolute_error: 0.0084
# Epoch 00394: val_loss did not improve from 0.00001
# 2000/2000 [==============================] - 4s 2ms/sample - loss: 1.1127e-04 - mean_absolute_error: 0.0083 - val_loss: 3.8220e-05 - val_mean_absolute_error: 0.0058
# Epoch 395/400
# 1984/2000 [============================>.] - ETA: 0s - loss: 9.5446e-05 - mean_absolute_error: 0.0082
# Epoch 00395: val_loss did not improve from 0.00001
# 2000/2000 [==============================] - 4s 2ms/sample - loss: 9.6271e-05 - mean_absolute_error: 0.0083 - val_loss: 3.6896e-05 - val_mean_absolute_error: 0.0046
# Epoch 396/400
# 1984/2000 [============================>.] - ETA: 0s - loss: 9.9195e-05 - mean_absolute_error: 0.0082
# Epoch 00396: val_loss did not improve from 0.00001
# 2000/2000 [==============================] - 4s 2ms/sample - loss: 9.9612e-05 - mean_absolute_error: 0.0082 - val_loss: 2.1310e-04 - val_mean_absolute_error: 0.0125
# Epoch 397/400
# 1984/2000 [============================>.] - ETA: 0s - loss: 1.6507e-04 - mean_absolute_error: 0.0110
# Epoch 00397: val_loss did not improve from 0.00001
# 2000/2000 [==============================] - 4s 2ms/sample - loss: 1.6525e-04 - mean_absolute_error: 0.0110 - val_loss: 5.6377e-05 - val_mean_absolute_error: 0.0066
# Epoch 398/400
# 1984/2000 [============================>.] - ETA: 0s - loss: 1.1825e-04 - mean_absolute_error: 0.0092
# Epoch 00398: val_loss did not improve from 0.00001
# 2000/2000 [==============================] - 4s 2ms/sample - loss: 1.1771e-04 - mean_absolute_error: 0.0092 - val_loss: 2.0794e-05 - val_mean_absolute_error: 0.0039
# Epoch 399/400
# 1984/2000 [============================>.] - ETA: 0s - loss: 8.7169e-05 - mean_absolute_error: 0.0077
# Epoch 00399: val_loss did not improve from 0.00001
# 2000/2000 [==============================] - 4s 2ms/sample - loss: 8.6841e-05 - mean_absolute_error: 0.0077 - val_loss: 3.5333e-05 - val_mean_absolute_error: 0.0064
# Epoch 400/400
# 1984/2000 [============================>.] - ETA: 0s - loss: 6.5445e-05 - mean_absolute_error: 0.0071
# Epoch 00400: val_loss did not improve from 0.00001
# 2000/2000 [==============================] - 4s 2ms/sample - loss: 6.5217e-05 - mean_absolute_error: 0.0071 - val_loss: 2.0395e-05 - val_mean_absolute_error: 0.0036

# %%
tensorboard --logdir="logs"
# Out:
#   File "<ipython-input-8-87357480c861>", line 1
#     tensorboard --logdir="logs"
#                                ^
# SyntaxError: can't assign to operator

# %%
data = load_data(ticker, N_STEPS, lookup_step=LOOKUP_STEP, test_size=TEST_SIZE,
                feature_columns=FEATURE_COLUMNS, shuffle=False)
# construct the model
model = create_model(N_STEPS, loss=LOSS, units=UNITS, cell=CELL, n_layers=N_LAYERS,
                    dropout=DROPOUT, optimizer=OPTIMIZER, bidirectional=BIDIRECTIONAL)
model_path = os.path.join("results", model_name) + ".h5"
model.load_weights(model_path)

# %%
# evaluate the model
mse, mae = model.evaluate(data["X_test"], data["y_test"], verbose=0)
# calculate the mean absolute error (inverse scaling)
mean_absolute_error = data["column_scaler"]["adjclose"].inverse_transform([[mae]])[0][0]
print("Mean Absolute Error:", mean_absolute_error)
# Out:
# Mean Absolute Error: 7.222729532764904

# %%
def predict(model, data):
    # retrieve the last sequence from data
    last_sequence = data["last_sequence"][-N_STEPS:]
    # retrieve the column scalers
    column_scaler = data["column_scaler"]
    # reshape the last sequence
    last_sequence = last_sequence.reshape((last_sequence.shape[1], last_sequence.shape[0]))
    # expand dimension
    last_sequence = np.expand_dims(last_sequence, axis=0)
    # get the prediction (scaled from 0 to 1)
    prediction = model.predict(last_sequence)
    # get the price (by inverting the scaling)
    predicted_price = column_scaler["adjclose"].inverse_transform(prediction)[0][0]
    return predicted_price

# %%
# predict the future price
future_price = predict(model, data)
print(f"Future price after {LOOKUP_STEP} days is {future_price:.2f}$")
# Out:
# Future price after 1 days is 368.31$

# %%
def plot_graph(model, data):
    y_test = data["y_test"]
    X_test = data["X_test"]
    y_pred = model.predict(X_test)
    y_test = np.squeeze(data["column_scaler"]["adjclose"].inverse_transform(np.expand_dims(y_test, axis=0)))
    y_pred = np.squeeze(data["column_scaler"]["adjclose"].inverse_transform(y_pred))
    # last 200 days, feel free to edit that
    plt.plot(y_test[-200:], c='b')
    plt.plot(y_pred[-200:], c='r')
    plt.xlabel("Days")
    plt.ylabel("Price")
    plt.legend(["Actual Price", "Predicted Price"])
    plt.show()

# %%
plot_graph(model, data)

# %%
def get_accuracy(model, data):
    y_test = data["y_test"]
    X_test = data["X_test"]
    y_pred = model.predict(X_test)
    y_test = np.squeeze(data["column_scaler"]["adjclose"].inverse_transform(np.expand_dims(y_test, axis=0)))
    y_pred = np.squeeze(data["column_scaler"]["adjclose"].inverse_transform(y_pred))
    y_pred = list(map(lambda current, future: int(float(future) > float(current)), y_test[:-LOOKUP_STEP], y_pred[LOOKUP_STEP:]))
    y_test = list(map(lambda current, future: int(float(future) > float(current)), y_test[:-LOOKUP_STEP], y_test[LOOKUP_STEP:]))
    return accuracy_score(y_test, y_pred)

# %%
print(str(LOOKUP_STEP) + ":", "Accuracy Score:", get_accuracy(model, data))
# Out:
# 1: Accuracy Score: 0.5450901803607214
